# %% [markdown]
# #GeoLife

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

import pyspark.sql.functions as f
import pyspark.sql.types as t 

from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, StandardScaler, VectorAssembler
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.classification import RandomForestClassifier
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Data Collection

# %%
# %sh
unzip /dbfs/FileStore/tables/Geolife_Trajectories_1_3.zip
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  /dbfs/FileStore/tables/Geolife_Trajectories_1_3.zip
#    creating: Geolife Trajectories 1.3/
#    creating: Geolife Trajectories 1.3/Data/
#    creating: Geolife Trajectories 1.3/Data/000/
#    creating: Geolife Trajectories 1.3/Data/000/Trajectory/
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081023025304.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081024020959.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081026134407.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081027115449.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081028003826.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081029092138.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081029093038.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081103101336.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081103232153.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081110013637.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081111001704.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081112023003.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081112091400.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081113034608.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081114015255.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081114101436.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081115010133.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081116085532.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081117051133.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081117155223.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081118095005.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081118095400.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081118162008.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081119012806.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081119112035.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081120035736.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081121040936.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081121113038.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081122012309.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081123102153.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081201111827.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081202071136.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081202071531.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081203032326.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081203151206.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081203234939.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081210023503.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081211044624.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081211121432.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081212042525.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081212101236.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20081214011036.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090330005208.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090331003904.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090401050607.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090401202331.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090402060732.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090403011657.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090405051938.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090406023702.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090409182800.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090410021935.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090411052358.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090412004905.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090412073303.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090413050806.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090413144632.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090413213935.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090415000406.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090415074008.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090416002705.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090417002430.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090418172238.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090419005226.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090419175500.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090420013034.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090420235106.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090422023859.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090422203607.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090423092838.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090423181101.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090424004737.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090424171137.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090425005731.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090426025714.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090426175513.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090427010230.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090427215826.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090428051631.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090429005954.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090430032332.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090501035138.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090502074907.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090503033926.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090504023301.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090504203925.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090505032432.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090505195337.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090506125906.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090507024201.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090507192952.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090508015405.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090508100431.plt
#   inflating: Geolife Trajectories 1.3/Data/000/Trajectory/20090509050136.

# %%
# %sh
cp -r 'Geolife Trajectories 1.3' /dbfs/FileStore/tables
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def load_data(user_id): 
    schema1 = t.StructType([t.StructField('StartTime', t.StringType(), True),
                            t.StructField('EndTime', t.StringType(), True),
                            t.StructField('TransportationMode', t.StringType(), True)])
    df1 = spark.createDataFrame([], schema=schema1).withColumn('ID', f.lit(None))
  
    schema2 = t.StructType([t.StructField('Latitude', t.DoubleType(), True),
                            t.StructField('Longitude', t.DoubleType(), True),
                            t.StructField('0', t.IntegerType(), True),
                            t.StructField('Altitude', t.IntegerType(), True),
                            t.StructField('Data1', t.DoubleType(), True),
                            t.StructField('Data', t.StringType(), True),
                            t.StructField('Time', t.StringType(), True)])
    df2 = spark.createDataFrame([], schema=schema2).withColumn('ID', f.lit(None))
    
    for num in np.arange(user_id):
      folder = '0' * (3 - len(str(num))) + str(num)
      
      try:
          df1 = df1.union(spark.read.csv(f'/FileStore/tables/Geolife Trajectories 1.3/Data/{folder}/labels.txt',
                          sep='\t', header=True).withColumn('ID', f.lit(int(num))))
          df2 = df2.union(spark.read.csv(f'/FileStore/tables/Geolife Trajectories 1.3/Data/{folder}/Trajectory/*.plt', 
                          schema=schema2, sep=',').withColumn("Index", f.monotonically_increasing_id()).filter('Index > 5')\
                          .drop('Index').withColumn('ID', f.lit(int(num))))
      except Exception as ex:
          pass
          
    return df1, df2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df
# %%
data = df_trajectory.join(df_labels, on=[df_trajectory['ID'] == df_labels['ID'], 
                          df_trajectory['Time'].between(df_labels['StartTime'], df_labels['EndTime'])],
                          how='inner').drop(df_trajectory['ID'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.orderBy('ID', 'Time').write.csv('/FileStore/tables/dataset.csv', header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Feature Engineering

# %%
custom_schema = t.StructType([t.StructField('Latitude', t.DoubleType(), True),
                              t.StructField('Longitude', t.DoubleType(), True),
                              t.StructField('Altitude', t.IntegerType(), True),
                              t.StructField('Time', t.TimestampType(), True),
                              t.StructField('StartTime', t.TimestampType(), True),
                              t.StructField('EndTime', t.TimestampType(), True),
                              t.StructField('TransportationMode', t.StringType(), True),
                              t.StructField('ID', t.IntegerType(), True)])
data = spark.read.csv('/FileStore/tables/dataset.csv', schema=custom_schema, header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Latitude</th><th>Longitude</th><th>Altitude</th><th>Time</th><th>StartTime</th><th>EndTime</th><th>TransportationMode</th><th>ID</th></tr></thead><tbody><tr><td>39.9965149</td><td>116.2732933</td><td>null</td><td>2009-02-21T07:46:21.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965333</td><td>116.27329</td><td>null</td><td>2009-02-21T07:46:23.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965483</td><td>116.2732933</td><td>null</td><td>2009-02-21T07:46:25.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.996565</td><td>116.2732949</td><td>null</td><td>2009-02-21T07:46:27.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965783</td><td>116.2733033</td><td>null</td><td>2009-02-21T07:46:29.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965883</td><td>116.2732999</td><td>null</td><td>2009-02-21T07:46:31.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965816</td><td>116.2732983</td><td>null</td><td>2009-02-21T07:46:34.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965883</td><td>116.2732966</td><td>null</td><td>2009-02-21T07:46:36.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965666</td><td>116.2733166</td><td>null</td><td>2009-02-21T07:46:38.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965583</td><td>116.2733266</td><td>null</td><td>2009-02-21T07:46:40.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9965833</td><td>116.2733416</td><td>null</td><td>2009-02-21T07:46:42.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9966116</td><td>116.27336</td><td>null</td><td>2009-02-21T07:46:44.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9966583</td><td>116.2733533</td><td>null</td><td>2009-02-21T07:46:48.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9967</td><td>116.2733166</td><td>null</td><td>2009-02-21T07:46:50.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9967083</td><td>116.2732983</td><td>null</td><td>2009-02-21T07:46:52.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.99673</td><td>116.2732933</td><td>null</td><td>2009-02-21T07:46:54.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9967533</td><td>116.27329</td><td>null</td><td>2009-02-21T07:47:07.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.9967733</td><td>116.2732649</td><td>null</td><td>2009-02-21T07:47:09.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr><tr><td>39.99679</td><td>116.2732166</td><td>null</td><td>2009-02-21T07:47:13.000+0000</td><td>2009-02-21T07:02:45.000+0000</td><td>2009-02-21T09:06:53.000+0000</td><td>walk</td><td>128</td></tr ...

# %%
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 5509013</div>

# %%
display(data.groupBy('TransportationMode').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>count</th></tr></thead><tbody><tr><td>bus</td><td>1284449</td></tr><tr><td>airplane</td><td>9196</td></tr><tr><td>train</td><td>561037</td></tr><tr><td>boat</td><td>3566</td></tr><tr><td>taxi</td><td>243097</td></tr><tr><td>walk</td><td>1615614</td></tr><tr><td>subway</td><td>312758</td></tr><tr><td>car</td><td>517436</td></tr><tr><td>bike</td><td>959547</td></tr><tr><td>run</td><td>1975</td></tr><tr><td>motorcycle</td><td>338</td></tr></tbody></table></div>

# %%
data = data.dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data.groupBy('TransportationMode').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>count</th></tr></thead><tbody><tr><td>motorcycle</td><td>338</td></tr><tr><td>bus</td><td>1270771</td></tr><tr><td>airplane</td><td>9194</td></tr><tr><td>train</td><td>561031</td></tr><tr><td>boat</td><td>3566</td></tr><tr><td>taxi</td><td>240145</td></tr><tr><td>walk</td><td>1562198</td></tr><tr><td>subway</td><td>309706</td></tr><tr><td>run</td><td>1975</td></tr><tr><td>car</td><td>516195</td></tr><tr><td>bike</td><td>935250</td></tr></tbody></table></div>

# %%
data = data.withColumn('TransportationMode', f.regexp_replace('TransportationMode', 'car|taxi', 'cat/taxi'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_features(latitude_a, longitude_a, latitude_b, longitude_b, time_a, time_b, radius=6371):
    latitude_a, longitude_a, latitude_b, longitude_b = map(np.radians, [latitude_a, longitude_a, latitude_b, longitude_b,])
    dist_longitude = longitude_b - longitude_a
    dist_latitude = latitude_b - latitude_a

    area = np.sin(dist_latitude / 2) ** 2 + np.cos(latitude_a) * np.cos(latitude_b) * np.sin(dist_longitude / 2) ** 2
    central_angle = 2 * np.arcsin(np.sqrt(area))

    distance = abs(central_angle * radius)
    time = abs((time_b - time_a).total_seconds()) / 3600
    velocity = distance / time if time != 0 else np.nan
    angle = np.arctan2(np.sin(longitude_b - longitude_a) * np.cos(latitude_b), np.cos(latitude_a) * np.sin(latitude_b) -\
                       np.sin(latitude_a) * np.cos(latitude_b) * np.cos(longitude_b - longitude_a))
  
    x = radius * np.cos(latitude_a) * np.cos(longitude_a)
    y = radius * np.cos(latitude_a) * np.sin(longitude_a)
    z = radius * np.sin(latitude_a)
    
    return {'Distance': float(distance), 'Time': float(time), 'Velocity': float(velocity), 'Angle': float(angle),
            'X': float(x), 'Y': float(y), 'Z': float(z)}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
features = f.udf(get_features, t.MapType(t.StringType(), t.DoubleType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_windows = data.groupby('ID', 'TransportationMode', f.window('Time', '30 seconds')\
                 .alias('Window')).agg(features(f.collect_list('Latitude')[0], f.collect_list('Longitude')[0],
                  f.reverse(f.collect_list('Latitude'))[0], f.reverse(f.collect_list('Longitude'))[0],
                  f.collect_list('Time')[0], f.reverse(f.collect_list('Time'))[0]).alias('map'))\
                 .orderBy('ID', 'Window')
df_windows.cache()

df_windows = df_windows.withColumn('Distance', df_windows.map['Distance'])\
                       .withColumn('Time', df_windows.map['Time'])\
                       .withColumn('Velocity', df_windows.map['Velocity'])\
                       .withColumn('Angle', df_windows.map['Angle'])\
                       .withColumn('X', df_windows.map['X'])\
                       .withColumn('Y', df_windows.map['Y'])\
                       .withColumn('Z', df_windows.map['Z'])\
                       .drop('Window', 'map')

df_windows = df_windows.filter(df_windows['Velocity'] != np.nan)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df
td></tr><tr><td>10</td><td>train</td><td>0.0</td><td>5.555555555555556E-4</td><td>0.0</td><td>0.0</td><td>-2395.548818784998</td><td>4651.390636043532</td><td>3635.320069504796</td></tr><tr><td>10</td><td>train</td><td>0.0</td><td>5.555555555555556E-4</td><td>0.0</td><td>0.0</td><td>-2406.9163542651986</td><td>4682.974342580796</td><td>3586.941032453795</td></tr><tr><td>10</td><td>train</td><td>0.0</td><td>5.555555555555556E-4</td><td>0.0</td><td>0.0</td><td>-2406.904093589518</td><td>4682.976420872572</td><td>3586.9465462721264</td></tr><tr><td>10</td><td>train</td><td>0.0</td><td>5.555555555555556E-4</td><td>0.0</td><td>0.0</td><td>-2406.8994970276735</td><td>4682.984766402865</td><td>35 ...

# %% [markdown]
# ## Machine Learning

# %%
custom_schema = t.StructType([t.StructField('ID', t.IntegerType(), True),
                              t.StructField('TransportationMode', t.StringType(), True),
                              t.StructField('Distance', t.DoubleType(), True),
                              t.StructField('Time', t.DoubleType(), True),
                              t.StructField('Velocity', t.DoubleType(), True),
                              t.StructField('Angle', t.DoubleType(), True),
                              t.StructField('X', t.DoubleType(), True),
                              t.StructField('Y', t.DoubleType(), True),
                              t.StructField('Z', t.DoubleType(), True)])
X = spark.createDataFrame([], schema=custom_schema)

for mode in df_windows.select('TransportationMode').distinct().collect():
    X = X.union(df_windows.filter(df_windows['TransportationMode'] == mode.TransportationMode).orderBy(f.rand()).limit(400))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(X)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>TransportationMode</th><th>Distance</th><th>Time</th><th>Velocity</th><th>Angle</th><th>X</th><th>Y</th><th>Z</th></tr></thead><tbody><tr><td>10</td><td>train</td><td>0.4106142879520948</td><td>0.002777777777777778</td><td>147.82114366275414</td><td>1.4168940859527401</td><td>-2017.9374114581724</td><td>4831.697748983057</td><td>3629.3617160472645</td></tr><tr><td>167</td><td>train</td><td>0.1586270976449602</td><td>0.0025</td><td>63.450839057984076</td><td>-1.6613360777895358</td><td>-2216.702329625165</td><td>4268.162899467853</td><td>4178.3558064674835</td></tr><tr><td>167</td><td>train</td><td>0.797022845081863</td><td>0.006388888888888889</td><td>124.75140183890029</td><td>-2.4780403461011518</td><td>-2397.647069441995</td><td>4266.136055309598</td><td>4079.3397367691346</td></tr><tr><td>10</td><td>train</td><td>0.14824311550522065</td><td>0.001388888888888889</td><td>106.73504316375886</td><td>-2.8636001640629285</td><td>-2407.759013375513</td><td>4705.106645229034</td><td>3557.289556745495</td></tr><tr><td>153</td><td>train</td><td>0.10712484469830526</td><td>0.001388888888888889</td><td>77.12988818277978</td><td>-2.9551428019134645</td><td>-2079.7100163038813</td><td>4567.603872876832</td><td>3924.4671114134558</td></tr><tr><td>10</td><td>train</td><td>0.25945000769053794</td><td>0.004166666666666667</td><td>62.26800184572911</td><td>-1.3784526328976605</td><td>-1493.161997274245</td><td>5033.781321019119</td><td>3608.483595924333</td></tr><tr><td>10</td><td>train</td><td>0.32691911228204207</td><td>0.004166666666666667</td><td>78.4605869476901</td><td>1.5367590164692395</td><td>-1904.438536333811</td><td>4877.845418594146</td><td>3628.963892576892</td></tr><tr><td>10</td><td>train</td><td>0.37448279472611123</td><td>0.0038888888888888888</td><td>96.29557578671432</td><td>-0.3573855198815521</td><td>-1276.2305066241502</td><td>5009.596179621172</td><td>3723.5497594482094</td></tr><tr><td>10</td><td>train</td><td>0.4370838551823888</td><td>0.002777777777777778</td><td>157.35018786565996</td><td>-0.46974397340544727</td><td>-2171.2269601369685</td><td>4391.691909735431</td><td>4072.8929101486005</td></tr><tr><td>10</td><td>train</td><td>0.06199487925635094</td><td>0.002777777777777778</td><td>22.318156532286338</td><td>-0.07418181928478704</td><td>-2406.8557163002793</td><td>4682.820379861316</td><td>3587.1827177979376</td></tr><tr><td>10</td><td>train</td><td>0.6505537400561036</td><td>0.006944444444444444</td><td>93.67973856807892</td><td>-1.8786565349694817</td><td>-96.0920395107499</td><td>5492.643907657003</td><td>3226.6500001737186</td></tr><tr><td>68</td><td>train</td><td>0.00782316914990715</td><td>0.0016666666666666668</td><td>4.69390148994429</td><td>1.1614830539170895</td><td>-2252.14463977547</td><td>4998.864398606162</td><td>3244.8174441528263</td></tr><tr><td>153</td><td>train</td><td>0.4544271272140723</td><td>0.006111111111111111</td><td>74.36080263503001</td><td>-0.00547874789793172</td><td>-2176.315360427016</td><td>4879.543820184118</td><td>3470.352224036116</td></tr><tr><td>126</td><td>train</td><td>0.21025899831444625</td><td>0.0019444444444444444</td><td>108.13319913314379</td><td>1.4333792130020775</td><td>-2204.208447200185</td><td>4359.151674740719</td><td>4090.098140374694</td></tr><tr><td>68</td><td>train</td><td>0.38626192067787746</td><td>0.002777777777777778</td><td>139.05429144403587</td><td>-0.9356181630986671</td><td>-2239.705235012536</td><td>4986.584684824541</td><td>3272.206387337263</td></tr><tr><td>10</td><td>train</td><td>0.19114752217363726</td><td>0.0019444444444444444</td><td>98.30443997501345</td><td>1.9198886326262947</td><td>-162.95030060810083</td><td>5419.731549995532</td><td>3345.0856678887553</td></tr><tr><td>84</td><td>train</td><td>0.16612122893434053</td><td>0.0011111111111111111</td><td>149.5091060409065</td><td>2.9409705832627044</td><td>-2 ...

# %%
display(X.groupBy('TransportationMode').count().orderBy('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>count</th></tr></thead><tbody><tr><td>cat/taxi</td><td>400</td></tr><tr><td>bus</td><td>400</td></tr><tr><td>train</td><td>400</td></tr><tr><td>airplane</td><td>400</td></tr><tr><td>bike</td><td>400</td></tr><tr><td>boat</td><td>400</td></tr><tr><td>walk</td><td>400</td></tr><tr><td>subway</td><td>400</td></tr><tr><td>run</td><td>144</td></tr><tr><td>motorcycle</td><td>24</td></tr></tbody></table></div>

# %%
train, test = X.randomSplit([0.8, 0.2], seed=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vector_assembler = VectorAssembler(inputCols=['Time', 'Velocity', 'Angle', 'X', 'Y', 'Z'], outputCol='Vector')
scaler = StandardScaler(withMean=True, withStd=True, inputCol='Vector', outputCol='features')
label_encoder = StringIndexer(inputCol='TransportationMode', outputCol='label', stringOrderType='frequencyDesc', handleInvalid='keep') 

forest = RandomForestClassifier(featuresCol='features', labelCol='label', maxDepth=5, impurity='gini', numTrees=100, featureSubsetStrategy='auto')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pipeline = Pipeline(stages=[vector_assembler, scaler, label_encoder, forest])
clf_forest = pipeline.fit(train)
pred = clf_forest.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(pred.select('label').distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th></tr></thead><tbody><tr><td>7.0</td></tr><tr><td>4.0</td></tr><tr><td>0.0</td></tr><tr><td>6.0</td></tr><tr><td>2.0</td></tr><tr><td>1.0</td></tr><tr><td>5.0</td></tr><tr><td>3.0</td></tr><tr><td>8.0</td></tr><tr><td>9.0</td></tr></tbody></table></div>

# %%
display(pred.select('prediction').distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prediction</th></tr></thead><tbody><tr><td>0.0</td></tr><tr><td>7.0</td></tr><tr><td>4.0</td></tr><tr><td>2.0</td></tr><tr><td>6.0</td></tr><tr><td>5.0</td></tr><tr><td>3.0</td></tr><tr><td>8.0</td></tr><tr><td>1.0</td></tr></tbody></table></div>

# %%
f1_score =  MulticlassClassificationEvaluator(metricName='f1')
accuracy = MulticlassClassificationEvaluator(metricName='accuracy')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(f'F1-score of training: {f1_score.evaluate(clf_forest.transform(train))}')
print(f'Accuracy of training: {accuracy.evaluate(clf_forest.transform(train))}')

print(f'F1-score of test: {f1_score.evaluate(pred)}')
print(f'Accuracy of test: {accuracy.evaluate(pred)}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">F1-score of training: 0.6382934686783267
# Accuracy of training: 0.6512231282431431
# F1-score of test: 0.6284338004800658
# Accuracy of test: 0.6432835820895523
# </div>

# %%
display(pred.select('TransportationMode', 'label', 'prediction'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>label</th><th>prediction</th></tr></thead><tbody><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>4.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>5.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>2.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>6.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></t ...

# %%
param_grid = ParamGridBuilder().addGrid(forest.maxDepth, [5, 10, 30])\
                               .addGrid(forest.numTrees, [20, 50, 100, 300]).build()

cv = CrossValidator(estimator=pipeline, estimatorParamMaps=param_grid, evaluator=f1_score, numFolds=5, parallelism=4)
clf_forest_tuned = cv.fit(train)
pred_tuned = clf_forest_tuned.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">MLlib will automatically track trials in MLflow. After your tuning fit() call has completed, view the MLflow UI to see logged runs.
# </div>

# %%
print(f'F1-score of test: {f1_score.evaluate(pred_tuned)}')
print(f'Accuracy of test: {accuracy.evaluate(pred_tuned)}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">F1-score of test: 0.7277325873918339
# Accuracy of test: 0.7328358208955223
# </div>

# %%
display(pred_tuned.select('TransportationMode', 'label', 'prediction'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>label</th><th>prediction</th></tr></thead><tbody><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>0.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></tr><tr><td>train</td><td>7.0</td><td>4.0</td></tr><tr><td>train</td><td>7.0</td><td>7.0</td></t ...

# %%
df_pred = pred.toPandas()
d = df_pred[['TransportationMode', 'label']].drop_duplicates().set_index('label').to_dict()['TransportationMode']
metrics = MulticlassMetrics(pred_tuned.select('label', 'prediction').rdd.map(lambda x: tuple(map(float, x))))
confusion_matrix = metrics.confusionMatrix().toArray()
labels = [d[i] for i in metrics.call('labels')]
pd.DataFrame(confusion_matrix , index=labels, columns=labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:93: UserWarning: toPandas attempted Arrow optimization because &#39;spark.sql.execution.arrow.pyspark.enabled&#39; is set to true; however, failed by the reason below:
#   Unable to convert the field Vector. If this column is not necessary, you may consider dropping it or converting to primitive type before the conversion.
# Context: Unsupported type in conversion to Arrow: VectorUDT
# Attempting non-optimization as &#39;spark.sql.execution.arrow.pyspark.fallback.enabled&#39; is set to true.
#   warnings.warn(msg)
# /databricks/spark/python/pyspark/sql/context.py:120: DeprecationWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   DeprecationWarning)
# Out[50]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cat/taxi</th>
#       <th>airplane</th>
#       <th>subway</th>
#       <th>boat</th>
#       <th>bus</th>
#       <th>bike</th>
#       <th>walk</th>
#       <th>train</th>
#       <th>run</th>
#       <th>motorcycle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>cat/taxi</th>
#       <td>36.0</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>17.0</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>7.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>airplane</th>
#       <td>1.0</td>
#       <td>68.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>subway</th>
#       <td>7.0</td>
#       <td>0.0</td>
#       <td>57.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>9.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>boat</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>79.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>bus</th>
#       <td>11.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>29.0</td>
#       <td>5.0</td>
#       <td>10.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>bike</th>
#       <td>4.0</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>0.0</td>
#       <td>10.0</td>
#       <td>66.0</td>
#       <td>6.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>walk</th>
#       <td>7.0</td>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>0.0</td>
#       <td>20.0</td>
#       <td>7.0</td>
#       <td>49.0</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>train</th>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>4.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>82.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>run</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>0.0</td>
#       <td>22.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>motorcycle</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Spark Streaming

# %%
def preprocessing(data):
    data = data.withColumn('TransportationMode', f.regexp_replace('TransportationMode', 'car|taxi', 'cat/taxi'))
    
    df = data.groupby('ID', 'TransportationMode', f.window('Time', '30 seconds')\
             .alias('Window')).agg(features(f.collect_list('Latitude')[0], f.collect_list('Longitude')[0],
              f.reverse(f.collect_list('Latitude'))[0], f.reverse(f.collect_list('Longitude'))[0],
              f.collect_list('Time')[0], f.reverse(f.collect_list('Time'))[0]).alias('map'))\
             .orderBy('ID', 'Window')

    df = df.withColumn('Distance', df.map['Distance']).withColumn('Time', df.map['Time'])\
           .withColumn('Velocity', df.map['Velocity']).withColumn('Angle', df.map['Angle'])\
           .withColumn('X', df.map['X']).withColumn('Y', df.map['Y'])\
           .withColumn('Z', df.map['Z']).drop('Window', 'map')

    df = df.filter(df['Velocity'] != np.nan) 
    
    return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
custom_schema = t.StructType([t.StructField('Latitude', t.DoubleType(), True),
                              t.StructField('Longitude', t.DoubleType(), True),
                              t.StructField('Altitude', t.IntegerType(), True),
                              t.StructField('Time', t.TimestampType(), True),
                              t.StructField('StartTime', t.TimestampType(), True),
                              t.StructField('EndTime', t.TimestampType(), True),
                              t.StructField('TransportationMode', t.StringType(), True),
                              t.StructField('ID', t.IntegerType(), True)])

stream_data = spark.readStream.schema(custom_schema).option('header', True).option('maxFilesPerTrigger', 1)\
                   .format('csv').load('/FileStore/tables/data.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stream_preprocessed = preprocessing(stream_data)
stream_pred = clf_forest_tuned.transform(stream_preprocessed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(stream_pred.select('TransportationMode', 'label', 'prediction'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>label</th><th>prediction</th></tr></thead><tbody><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</ ...

# %%
display(stream_pred.select('TransportationMode', 'label', 'prediction'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TransportationMode</th><th>label</th><th>prediction</th></tr></thead><tbody><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>7.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>0.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</td><td>4.0</td></tr><tr><td>bus</td><td>4.0</ ...
